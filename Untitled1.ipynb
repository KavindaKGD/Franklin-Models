# %% [markdown]
# <a href="https://colab.research.google.com/github/KavindaKGD/Franklin-Models/blob/Triplet/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TF:", tf.__version__)
# Out:
# TF: 2.19.0

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_ROOT = "/content/drive/MyDrive/fp_dataset"  # <-- change
TRAIN_DIR = os.path.join(DATA_ROOT, "train")
VAL_DIR   = os.path.join(DATA_ROOT, "val")

CLASS_NAMES = ["fp", "healthy", "barnacles"]  # must match folder names exactly
N_WAY = 3

for c in CLASS_NAMES:
    print(c, "train:", len(os.listdir(os.path.join(TRAIN_DIR, c))),
             "val:", len(os.listdir(os.path.join(VAL_DIR, c))))
# Out:
# fp train: 4 val: 2
# healthy train: 4 val: 2
# barnacles train: 4 val: 2

# %%
def list_images_by_class(base_dir, class_names):
    by_class = {}
    for idx, cname in enumerate(class_names):
        cdir = os.path.join(base_dir, cname)
        files = []
        for f in os.listdir(cdir):
            if f.lower().endswith((".jpg", ".jpeg", ".png", ".webp")):
                files.append(os.path.join(cdir, f))
        by_class[idx] = sorted(files)
    return by_class

train_by_class = list_images_by_class(TRAIN_DIR, CLASS_NAMES)
val_by_class   = list_images_by_class(VAL_DIR, CLASS_NAMES)

print("Train by class:", {k: len(v) for k, v in train_by_class.items()})
print("Val by class:", {k: len(v) for k, v in val_by_class.items()})
# Out:
# Train by class: {0: 4, 1: 4, 2: 4}
# Val by class: {0: 2, 1: 2, 2: 2}

# %%
IMG_SIZE = 224
BATCH_SIZE = 16

augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomZoom(0.10),
])

def load_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0
    return img

# %%
def resnet_basic_block(x, filters, stride=1, name="block"):
    shortcut = x

    x = tf.keras.layers.Conv2D(filters, 3, strides=stride, padding="same",
                               use_bias=False, name=name+"_conv1")(x)
    x = tf.keras.layers.BatchNormalization(name=name+"_bn1")(x)
    x = tf.keras.layers.ReLU(name=name+"_relu1")(x)

    x = tf.keras.layers.Conv2D(filters, 3, strides=1, padding="same",
                               use_bias=False, name=name+"_conv2")(x)
    x = tf.keras.layers.BatchNormalization(name=name+"_bn2")(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = tf.keras.layers.Conv2D(filters, 1, strides=stride, padding="same",
                                          use_bias=False, name=name+"_down_conv")(shortcut)
        shortcut = tf.keras.layers.BatchNormalization(name=name+"_down_bn")(shortcut)

    x = tf.keras.layers.Add(name=name+"_add")([x, shortcut])
    x = tf.keras.layers.ReLU(name=name+"_out")(x)
    return x

def build_resnet18_encoder(embedding_dim=128, dropout=0.2):
    inp = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="image")

    # Stem
    x = tf.keras.layers.Conv2D(64, 7, strides=2, padding="same", use_bias=False, name="stem_conv")(inp)
    x = tf.keras.layers.BatchNormalization(name="stem_bn")(x)
    x = tf.keras.layers.ReLU(name="stem_relu")(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same", name="stem_pool")(x)

    # [2,2,2,2]
    x = resnet_basic_block(x, 64,  stride=1, name="s1_b1")
    x = resnet_basic_block(x, 64,  stride=1, name="s1_b2")

    x = resnet_basic_block(x, 128, stride=2, name="s2_b1")
    x = resnet_basic_block(x, 128, stride=1, name="s2_b2")

    x = resnet_basic_block(x, 256, stride=2, name="s3_b1")
    x = resnet_basic_block(x, 256, stride=1, name="s3_b2")

    x = resnet_basic_block(x, 512, stride=2, name="s4_b1")
    x = resnet_basic_block(x, 512, stride=1, name="s4_b2")

    x = tf.keras.layers.GlobalAveragePooling2D(name="gap")(x)
    if dropout and dropout > 0:
        x = tf.keras.layers.Dropout(dropout, name="drop")(x)

    x = tf.keras.layers.Dense(embedding_dim, name="emb_dense")(x)
    out = tf.keras.layers.Lambda(lambda t: tf.math.l2_normalize(t, axis=-1),
                                 name="l2norm")(x)

    return tf.keras.Model(inp, out, name="ResNet18_Encoder")

encoder = build_resnet18_encoder(embedding_dim=128, dropout=0.2)
encoder.summary()
# Out:
# Model: "ResNet18_Encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │      9,408 │ image[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        256 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_relu (ReLU)    │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 56, 56,    │          0 │ stem_relu[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_conv1         │ (None, 56, 56,    │     36,864 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_bn1           │ (None, 56, 56,    │        256 │ s1_b1_conv1[0][0] │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_relu1 (ReLU)  │ (None, 56, 56,    │          0 │ s1_b1_bn1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_conv2         │ (None, 56, 56,    │     36,864 │ s1_b1_relu1[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_bn2           │ (None, 56, 56,    │        256 │ s1_b1_conv2[0][0] │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_add (Add)     │ (None, 56, 56,    │          0 │ s1_b1_bn2[0][0],  │
# │                     │ 64)               │            │ stem_pool[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_out (ReLU)    │ (None, 56, 56,    │          0 │ s1_b1_add[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_conv1         │ (None, 56, 56,    │     36,864 │ s1_b1_out[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_bn1           │ (None, 56, 56,    │        256 │ s1_b2_conv1[0][0] │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_relu1 (ReLU)  │ (None, 56, 56,    │          0 │ s1_b2_bn1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_conv2         │ (None, 56, 56,    │     36,864 │ s1_b2_relu1[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_bn2           │ (None, 56, 56,    │        256 │ s1_b2_conv2[0][0] │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_add (Add)     │ (None, 56, 56,    │          0 │ s1_b2_bn2[0][0],  │
# │                     │ 64)               │            │ s1_b1_out[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_out (ReLU)    │ (None, 56, 56,    │          0 │ s1_b2_add[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_conv1         │ (None, 28, 28,    │     73,728 │ s1_b2_out[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_bn1           │ (None, 28, 28,    │        512 │ s2_b1_conv1[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_relu1 (ReLU)  │ (None, 28, 28,    │          0 │ s2_b1_bn1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_conv2         │ (None, 28, 28,    │    147,456 │ s2_b1_relu1[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_down_conv     │ (None, 28, 28,    │      8,192 │ s1_b2_out[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_bn2           │ (None, 28, 28,    │        512 │ s2_b1_conv2[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_down_bn       │ (None, 28, 28,    │        512 │ s2_b1_down_conv[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_add (Add)     │ (None, 28, 28,    │          0 │ s2_b1_bn2[0][0],  │
# │                     │ 128)              │            │ s2_b1_down_bn[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_out (ReLU)    │ (None, 28, 28,    │          0 │ s2_b1_add[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_conv1         │ (None, 28, 28,    │    147,456 │ s2_b1_out[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_bn1           │ (None, 28, 28,    │        512 │ s2_b2_conv1[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_relu1 (ReLU)  │ (None, 28, 28,    │          0 │ s2_b2_bn1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_conv2         │ (None, 28, 28,    │    147,456 │ s2_b2_relu1[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_bn2           │ (None, 28, 28,    │        512 │ s2_b2_conv2[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_add (Add)     │ (None, 28, 28,    │          0 │ s2_b2_bn2[0][0],  │
# │                     │ 128)              │            │ s2_b1_out[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_out (ReLU)    │ (None, 28, 28,    │          0 │ s2_b2_add[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_conv1         │ (None, 14, 14,    │    294,912 │ s2_b2_out[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_bn1           │ (None, 14, 14,    │      1,024 │ s3_b1_conv1[0][0] │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_relu1 (ReLU)  │ (None, 14, 14,    │          0 │ s3_b1_bn1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_conv2         │ (None, 14, 14,    │    589,824 │ s3_b1_relu1[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_down_conv     │ (None, 14, 14,    │     32,768 │ s2_b2_out[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_bn2           │ (None, 14, 14,    │      1,024 │ s3_b1_conv2[0][0] │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_down_bn       │ (None, 14, 14,    │      1,024 │ s3_b1_down_conv[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_add (Add)     │ (None, 14, 14,    │          0 │ s3_b1_bn2[0][0],  │
# │                     │ 256)              │            │ s3_b1_down_bn[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_out (ReLU)    │ (None, 14, 14,    │          0 │ s3_b1_add[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_conv1         │ (None, 14, 14,    │    589,824 │ s3_b1_out[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_bn1           │ (None, 14, 14,    │      1,024 │ s3_b2_conv1[0][0] │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_relu1 (ReLU)  │ (None, 14, 14,    │          0 │ s3_b2_bn1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_conv2         │ (None, 14, 14,    │    589,824 │ s3_b2_relu1[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_bn2           │ (None, 14, 14,    │      1,024 │ s3_b2_conv2[0][0] │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_add (Add)     │ (None, 14, 14,    │          0 │ s3_b2_bn2[0][0],  │
# │                     │ 256)              │            │ s3_b1_out[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_out (ReLU)    │ (None, 14, 14,    │          0 │ s3_b2_add[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_conv1         │ (None, 7, 7, 512) │  1,179,648 │ s3_b2_out[0][0]   │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_bn1           │ (None, 7, 7, 512) │      2,048 │ s4_b1_conv1[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_relu1 (ReLU)  │ (None, 7, 7, 512) │          0 │ s4_b1_bn1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_conv2         │ (None, 7, 7, 512) │  2,359,296 │ s4_b1_relu1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_down_conv     │ (None, 7, 7, 512) │    131,072 │ s3_b2_out[0][0]   │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_bn2           │ (None, 7, 7, 512) │      2,048 │ s4_b1_conv2[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_down_bn       │ (None, 7, 7, 512) │      2,048 │ s4_b1_down_conv[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_add (Add)     │ (None, 7, 7, 512) │          0 │ s4_b1_bn2[0][0],  │
# │                     │                   │            │ s4_b1_down_bn[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b1_out (ReLU)    │ (None, 7, 7, 512) │          0 │ s4_b1_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_conv1         │ (None, 7, 7, 512) │  2,359,296 │ s4_b1_out[0][0]   │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_bn1           │ (None, 7, 7, 512) │      2,048 │ s4_b2_conv1[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_relu1 (ReLU)  │ (None, 7, 7, 512) │          0 │ s4_b2_bn1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_conv2         │ (None, 7, 7, 512) │  2,359,296 │ s4_b2_relu1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_bn2           │ (None, 7, 7, 512) │      2,048 │ s4_b2_conv2[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_add (Add)     │ (None, 7, 7, 512) │          0 │ s4_b2_bn2[0][0],  │
# │                     │                   │            │ s4_b1_out[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s4_b2_out (ReLU)    │ (None, 7, 7, 512) │          0 │ s4_b2_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ s4_b2_out[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop (Dropout)      │ (None, 512)       │          0 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emb_dense (Dense)   │ (None, 128)       │     65,664 │ drop[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l2norm (Lambda)     │ (None, 128)       │          0 │ emb_dense[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,251,776 (42.92 MB)
#  Trainable params: 11,242,176 (42.89 MB)
#  Non-trainable params: 9,600 (37.50 KB)

# %%
def build_all_triplets(by_class):
    triplets = []
    classes = list(by_class.keys())

    for c in classes:
        pos_files = by_class[c]
        neg_files = []
        for other in classes:
            if other != c:
                neg_files += by_class[other]

        for a in pos_files:
            for p in pos_files:
                if a == p:
                    continue
                for n in neg_files:
                    triplets.append((a, p, n))

    random.shuffle(triplets)
    return triplets

train_triplets = build_all_triplets(train_by_class)
val_triplets   = build_all_triplets(val_by_class)

print("Train triplets:", len(train_triplets))
print("Val triplets:", len(val_triplets))
# Out:
# Train triplets: 288
# Val triplets: 24

# %%
def make_triplet_dataset(triplets, training=True):
    a = [t[0] for t in triplets]
    p = [t[1] for t in triplets]
    n = [t[2] for t in triplets]

    ds = tf.data.Dataset.from_tensor_slices((a, p, n))

    def _map(pa, pp, pn):
        ia = load_image(pa)
        ip = load_image(pp)
        inn = load_image(pn)
        if training:
            ia  = augment(ia, training=True)
            ip  = augment(ip, training=True)
            inn = augment(inn, training=True)
        return (ia, ip, inn)

    ds = ds.map(_map, num_parallel_calls=tf.data.AUTOTUNE)
    if training:
        ds = ds.shuffle(512, seed=SEED, reshuffle_each_iteration=True)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

train_ds = make_triplet_dataset(train_triplets, training=True)
val_ds   = make_triplet_dataset(val_triplets, training=False)

# %%
class TripletModel(tf.keras.Model):
    def __init__(self, encoder, margin=0.3):
        super().__init__()
        self.encoder = encoder
        self.margin = margin
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        return [self.loss_tracker]

    def call(self, inputs, training=False):
        a, p, n = inputs
        za = self.encoder(a, training=training)
        zp = self.encoder(p, training=training)
        zn = self.encoder(n, training=training)
        return za, zp, zn

    def triplet_loss(self, za, zp, zn):
        d_ap = tf.reduce_sum(tf.square(za - zp), axis=1)
        d_an = tf.reduce_sum(tf.square(za - zn), axis=1)
        loss = tf.maximum(0.0, d_ap - d_an + self.margin)
        return tf.reduce_mean(loss)

    def train_step(self, data):
        a, p, n = data
        with tf.GradientTape() as tape:
            za, zp, zn = self((a, p, n), training=True)
            loss = self.triplet_loss(za, zp, zn)

        grads = tape.gradient(loss, self.encoder.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.encoder.trainable_variables))

        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        a, p, n = data
        za, zp, zn = self((a, p, n), training=False)
        loss = self.triplet_loss(za, zp, zn)
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

triplet_model = TripletModel(encoder, margin=0.3)
triplet_model.compile(optimizer=tf.keras.optimizers.Adam(1e-4))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

def compute_prototypes(encoder, by_class):
    protos = []
    for c in range(N_WAY):
        imgs = [load_image(p) for p in by_class[c]]
        imgs = tf.stack(imgs)
        z = encoder(imgs, training=False)
        protos.append(tf.reduce_mean(z, axis=0))
    return tf.stack(protos)  # (3, D)

def predict_with_prototypes(encoder, prototypes, img):
    z = encoder(tf.expand_dims(img, 0), training=False)  # (1, D)
    dists = tf.reduce_sum(tf.square(z - tf.expand_dims(prototypes, 0)), axis=-1)  # (1, 3)
    return int(tf.argmin(dists, axis=1).numpy()[0])

def eval_3class(encoder, train_by_class, val_by_class):
    prototypes = compute_prototypes(encoder, train_by_class)
    y_true, y_pred = [], []
    for c in range(N_WAY):
        for p in val_by_class[c]:
            img = load_image(p)
            pred = predict_with_prototypes(encoder, prototypes, img)
            y_true.append(c)
            y_pred.append(pred)
    acc = accuracy_score(y_true, y_pred)
    cm  = confusion_matrix(y_true, y_pred, labels=[0,1,2])
    return acc, cm

# %%
EPOCHS = 80

train_loss_hist = []
val_loss_hist   = []
val_acc_hist    = []

for epoch in range(1, EPOCHS + 1):
    h = triplet_model.fit(train_ds, validation_data=val_ds, epochs=1, verbose=0)

    tr_loss = float(h.history["loss"][0])
    va_loss = float(h.history["val_loss"][0])

    acc, _ = eval_3class(encoder, train_by_class, val_by_class)

    train_loss_hist.append(tr_loss)
    val_loss_hist.append(va_loss)
    val_acc_hist.append(acc)

    print(f"Epoch {epoch:03d} | train triplet loss {tr_loss:.4f} | val triplet loss {va_loss:.4f} | val 3-class acc {acc:.3f}")
# Out:
# Epoch 001 | train triplet loss 0.0000 | val triplet loss 0.4674 | val 3-class acc 0.500
# Epoch 002 | train triplet loss 0.0000 | val triplet loss 0.4932 | val 3-class acc 0.667
# Epoch 003 | train triplet loss 0.0000 | val triplet loss 0.5061 | val 3-class acc 0.667
# Epoch 004 | train triplet loss 0.0006 | val triplet loss 0.5931 | val 3-class acc 0.500
# Epoch 005 | train triplet loss 0.0002 | val triplet loss 0.6860 | val 3-class acc 0.667
# Epoch 006 | train triplet loss 0.0000 | val triplet loss 0.7003 | val 3-class acc 0.500
# Epoch 007 | train triplet loss 0.0000 | val triplet loss 0.6965 | val 3-class acc 0.500
# Epoch 008 | train triplet loss 0.0000 | val triplet loss 0.6892 | val 3-class acc 0.500
# Epoch 009 | train triplet loss 0.0000 | val triplet loss 0.7062 | val 3-class acc 0.500
# Epoch 010 | train triplet loss 0.0000 | val triplet loss 0.7108 | val 3-class acc 0.500
# Epoch 011 | train triplet loss 0.0000 | val triplet loss 0.7100 | val 3-class acc 0.500
# Epoch 012 | train triplet loss 0.0000 | val triplet loss 0.7104 | val 3-class acc 0.500
# Epoch 013 | train triplet loss 0.0000 | val triplet loss 0.7110 | val 3-class acc 0.500
# Epoch 014 | train triplet loss 0.0000 | val triplet loss 0.7112 | val 3-class acc 0.500
# Epoch 015 | train triplet loss 0.0000 | val triplet loss 0.7096 | val 3-class acc 0.500
# Epoch 016 | train triplet loss 0.0000 | val triplet loss 0.7085 | val 3-class acc 0.500
# Epoch 017 | train triplet loss 0.0000 | val triplet loss 0.7091 | val 3-class acc 0.500
# Epoch 018 | train triplet loss 0.0000 | val triplet loss 0.7078 | val 3-class acc 0.500
# Epoch 019 | train triplet loss 0.0000 | val triplet loss 0.7109 | val 3-class acc 0.500
# Epoch 020 | train triplet loss 0.0000 | val triplet loss 0.7096 | val 3-class acc 0.500
# Epoch 021 | train triplet loss 0.0000 | val triplet loss 0.7068 | val 3-class acc 0.500
# Epoch 022 | train triplet loss 0.0000 | val triplet loss 0.7064 | val 3-class acc 0.500
# Epoch 023 | train triplet loss 0.0000 | val triplet loss 0.7082 | val 3-class acc 0.500
# Epoch 024 | train triplet loss 0.0000 | val triplet loss 0.7089 | val 3-class acc 0.500
# Epoch 025 | train triplet loss 0.0000 | val triplet loss 0.7075 | val 3-class acc 0.500
# Epoch 026 | train triplet loss 0.0006 | val triplet loss 0.7180 | val 3-class acc 0.500
# Epoch 027 | train triplet loss 0.0016 | val triplet loss 0.7207 | val 3-class acc 0.500
# Epoch 028 | train triplet loss 0.0000 | val triplet loss 0.5526 | val 3-class acc 0.500
# Epoch 029 | train triplet loss 0.0000 | val triplet loss 0.5410 | val 3-class acc 0.500
# Epoch 030 | train triplet loss 0.0000 | val triplet loss 0.5471 | val 3-class acc 0.500
# Epoch 031 | train triplet loss 0.0000 | val triplet loss 0.5505 | val 3-class acc 0.500
# Epoch 032 | train triplet loss 0.0000 | val triplet loss 0.5532 | val 3-class acc 0.500
# Epoch 033 | train triplet loss 0.0000 | val triplet loss 0.5522 | val 3-class acc 0.500
# Epoch 034 | train triplet loss 0.0000 | val triplet loss 0.5519 | val 3-class acc 0.500
# Epoch 035 | train triplet loss 0.0012 | val triplet loss 0.3121 | val 3-class acc 0.500
# Epoch 036 | train triplet loss 0.0008 | val triplet loss 0.3837 | val 3-class acc 0.667
# Epoch 037 | train triplet loss 0.0000 | val triplet loss 0.4463 | val 3-class acc 0.667
# Epoch 038 | train triplet loss 0.0001 | val triplet loss 0.5034 | val 3-class acc 0.667
# Epoch 039 | train triplet loss 0.0000 | val triplet loss 0.5305 | val 3-class acc 0.667
# Epoch 040 | train triplet loss 0.0027 | val triplet loss 0.4933 | val 3-class acc 0.667
# Epoch 041 | train triplet loss 0.0000 | val triplet loss 0.5206 | val 3-class acc 0.667
# Epoch 042 | train triplet loss 0.0006 | val triplet loss 0.2862 | val 3-class acc 0.500
# Epoch 043 | train triplet loss 0.0024 | val triplet loss 0.5423 | val 3-class acc 0.667
# Epoch 044 | train triplet loss 0.0000 | val triplet loss 0.5947 | val 3-class acc 0.500
# Epoch 045 | train triplet loss 0.0003 | val triplet loss 0.6254 | val 3-class acc 0.500
# Epoch 046 | train triplet loss 0.0021 | val triplet loss 0.7035 | val 3-class acc 0.500
# Epoch 047 | train triplet loss 0.0000 | val triplet loss 0.7126 | val 3-class acc 0.500
# Epoch 048 | train triplet loss 0.0000 | val triplet loss 0.7063 | val 3-class acc 0.500
# Epoch 049 | train triplet loss 0.0000 | val triplet loss 0.6963 | val 3-class acc 0.500
# Epoch 050 | train triplet loss 0.0005 | val triplet loss 0.7032 | val 3-class acc 0.500
# Epoch 051 | train triplet loss 0.0011 | val triplet loss 0.7519 | val 3-class acc 0.500
# Epoch 052 | train triplet loss 0.0018 | val triplet loss 0.5210 | val 3-class acc 0.500
# Epoch 053 | train triplet loss 0.0000 | val triplet loss 0.8006 | val 3-class acc 0.667
# Epoch 054 | train triplet loss 0.0000 | val triplet loss 0.8081 | val 3-class acc 0.667
# Epoch 055 | train triplet loss 0.0007 | val triplet loss 0.7267 | val 3-class acc 0.667
# Epoch 056 | train triplet loss 0.0000 | val triplet loss 0.7709 | val 3-class acc 0.667
# Epoch 057 | train triplet loss 0.0075 | val triplet loss 0.6011 | val 3-class acc 0.667
# Epoch 058 | train triplet loss 0.0028 | val triplet loss 0.5297 | val 3-class acc 0.500
# Epoch 059 | train triplet loss 0.0001 | val triplet loss 0.7925 | val 3-class acc 0.500
# Epoch 060 | train triplet loss 0.0014 | val triplet loss 0.4825 | val 3-class acc 0.500
# Epoch 061 | train triplet loss 0.0000 | val triplet loss 0.3842 | val 3-class acc 0.500
# Epoch 062 | train triplet loss 0.0007 | val triplet loss 0.6380 | val 3-class acc 0.667
# Epoch 063 | train triplet loss 0.0000 | val triplet loss 0.7401 | val 3-class acc 0.500
# Epoch 064 | train triplet loss 0.0000 | val triplet loss 0.7044 | val 3-class acc 0.667
# Epoch 065 | train triplet loss 0.0000 | val triplet loss 0.6811 | val 3-class acc 0.667
# Epoch 066 | train triplet loss 0.0000 | val triplet loss 0.6641 | val 3-class acc 0.667
# Epoch 067 | train triplet loss 0.0000 | val triplet loss 0.6496 | val 3-class acc 0.667
# Epoch 068 | train triplet loss 0.0000 | val triplet loss 0.6385 | val 3-class acc 0.667
# Epoch 069 | train triplet loss 0.0006 | val triplet loss 0.5607 | val 3-class acc 0.667
# Epoch 070 | train triplet loss 0.0000 | val triplet loss 0.5888 | val 3-class acc 0.667
# Epoch 071 | train triplet loss 0.0000 | val triplet loss 0.6377 | val 3-class acc 0.667
# Epoch 072 | train triplet loss 0.0000 | val triplet loss 0.6608 | val 3-class acc 0.667
# Epoch 073 | train triplet loss 0.0000 | val triplet loss 0.6709 | val 3-class acc 0.667
# Epoch 074 | train triplet loss 0.0013 | val triplet loss 0.7881 | val 3-class acc 0.500
# Epoch 075 | train triplet loss 0.0000 | val triplet loss 0.8330 | val 3-class acc 0.500
# Epoch 076 | train triplet loss 0.0000 | val triplet loss 0.8241 | val 3-class acc 0.500
# Epoch 077 | train triplet loss 0.0000 | val triplet loss 0.8119 | val 3-class acc 0.500
# Epoch 078 | train triplet loss 0.0049 | val triplet loss 1.0845 | val 3-class acc 0.500
# Epoch 079 | train triplet loss 0.0000 | val triplet loss 0.2539 | val 3-class acc 0.667
# Epoch 080 | train triplet loss 0.0050 | val triplet loss 0.5058 | val 3-class acc 0.667

# %%
plt.figure()
plt.plot(train_loss_hist, label="train_triplet_loss")
plt.plot(val_loss_hist, label="val_triplet_loss")
plt.title("Triplet Loss (ResNet-18 Encoder)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure()
plt.plot(val_acc_hist, label="val_3class_acc")
plt.title("3-Class Validation Accuracy (Prototype Eval)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
SAVE_DIR = "/content/drive/MyDrive/sea_turtle_models"
os.makedirs(SAVE_DIR, exist_ok=True)

ENCODER_PATH = os.path.join(SAVE_DIR, "triplet_resnet18_encoder.keras")
encoder.save(ENCODER_PATH)
print("Saved:", ENCODER_PATH)
# Out:
# Saved: /content/drive/MyDrive/sea_turtle_models/triplet_resnet18_encoder.keras
